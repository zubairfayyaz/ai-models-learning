# %% [markdown]
# <a href="https://colab.research.google.com/github/zubairfayyaz/ai-models-learning/blob/main/newfile.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello world")
# Out:
# hello
